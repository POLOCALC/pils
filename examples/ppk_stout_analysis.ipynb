# %% [markdown]
# # PPK Analysis Workflow with StoutLoader
#
# This notebook demonstrates the complete PPK workflow for high-precision GPS positioning using the PPK module

# %% [markdown]
# Import Required Libraries

# %%
from pathlib import Path
import subprocess
import polars as pl
import numpy as np
import matplotlib.pyplot as plt

from pils.loader.stout import StoutLoader
from pils.flight import Flight
from pils.analyze.ppk import PPKAnalysis

# %matplotlib widget

print("✓ All imports successful")
# Out:
# ✓ All imports successful

# %% [markdown]
# ## Select Flight

# %%
loader = StoutLoader()
flight_meta = loader.load_single_flight(flight_name="flight_20251206_1304")
flight = Flight(flight_meta)
ppk = PPKAnalysis(flight)
res = ppk.run_analysis('/scratch/RTK Tests/optimized.conf', force=True, analyze_rinex=True, analyze_ppk=True)
# Out:
# 2026-03-02 15:18:44.486 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 15:18:44 - stout - WARNING - [authenticated_user] - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-03-02 15:18:44,416 - stout - WARNING - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-03-02 15:18:44.487 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 15:18:44 - stout - INFO - [authenticated_user] - Centralized logging system initialized
# 2026-03-02 15:18:44,488 - pils.loader.stout - INFO - Initialized with stout database, base path: /mnt/data/POLOCALC
# 2026-03-02 15:18:44,488 - pils.loader.stout - INFO - Loading single flight: flight_id=None, flight_name=flight_20251206_1304
# 2026-03-02 15:18:44,501 - pils.loader.stout - INFO - Loaded flight: flight_20251206_1304
# 2026-03-02 15:18:44,501 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304
# 2026-03-02 15:18:44,502 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/aux/sensors/20251206_130358_GPS.bin (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rover.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rover.nav
#
# scanning: 2025/12/06 13:15:23 GRESC
# 2025/12/06 13:02:05-12/06 13:15:24: O=1599 N=45 E=126
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/base/20251206_base.UBX (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/base.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/base.nav
#
# scanning: 2025/12/06 13:25:23 GRESC
# 2025/12/06 12:52:04-12/06 13:25:23: O=9995 N=170 E=1846
# 2026-03-02 15:18:45,318 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2026-03-02 15:18:45,645 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 333397 observations across 1599 epochs
# 2026-03-02 15:18:45,655 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-03-02 15:18:45,656 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk'
# 2026-03-02 15:18:45,656 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:18:52,734 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/report_rover.md
# 2026-03-02 15:18:52,735 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-03-02 15:18:54,869 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 2389920 observations across 9995 epochs
# 2026-03-02 15:18:54,941 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-03-02 15:18:54,942 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk'
# 2026-03-02 15:18:54,943 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:19:30,958 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/report_base.md
# 2026-03-02 15:19:30,958 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260302_151844
# 2026-03-02 15:19:30,958 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_151844/optimized.conf
# 2026-03-02 15:19:33,435 - pils.analyze.ppkdata.PPK.report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_151844'
# 2026-03-02 15:19:36,024 - pils.analyze.ppkdata.PPK.report - INFO - RTKLIB Quality Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_151844/report.md
# 2026-03-02 15:19:36,028 - pils.analyze.ppk - INFO - Parsed position: 1599 epochs
# 2026-03-02 15:19:36,210 - pils.analyze.ppk - INFO - Parsed statistics: 127072 records
# 2026-03-02 15:19:36,251 - pils.analyze.ppk - INFO - Saved version rev_20260302_151844 to HDF5
# 2026-03-02 15:19:36,251 - pils.analyze.ppk - INFO - PPK analysis complete: rev_20260302_151844

# %% [markdown]
# ## Load Flight Data
#
# Load flight information from STOUT database and extract key paths for GPS data processing.

# %%
loader = StoutLoader()

# Load single flight by ID
flight_meta = loader.load_flights_by_date('2025-12-06', '2025-12-06')
# Out:
# 2026-03-02 15:03:38.768 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 15:03:38 - stout - WARNING - [authenticated_user] - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-03-02 15:03:38,701 - stout - WARNING - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-03-02 15:03:38.769 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-02 15:03:38 - stout - INFO - [authenticated_user] - Centralized logging system initialized
# 2026-03-02 15:03:38,769 - pils.loader.stout - INFO - Initialized with stout database, base path: /mnt/data/POLOCALC
# 2026-03-02 15:03:38,770 - pils.loader.stout - INFO - Loading flights between 2025-12-06 and 2025-12-06
# 2026-03-02 15:03:38,783 - pils.loader.stout - INFO - Loaded 13 flights in date range

# %%
for fm in flight_meta:
    flight = Flight(fm)
    ppk = PPKAnalysis(flight)
    res = ppk.run_analysis('/scratch/RTK Tests/optimized.conf', force=True, analyze_rinex=True, analyze_ppk=True)
# Out:
# 2026-03-02 15:03:39,874 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1222
# 2026-03-02 15:03:39,874 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1222/proc/ppk
# 2026-03-02 15:03:39,875 - pils.analyze.ppk - INFO - Missing rover .bin file
# 2026-03-02 15:03:39,875 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231
# 2026-03-02 15:03:39,875 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/aux/sensors/20251206_123124_GPS.bin (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/rover.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/rover.nav
#
# scanning: 2025/12/06 12:42:07 GRESC
# 2025/12/06 12:30:40-12/06 12:42:07: O=1375 N=50 E=102
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/base/20251206_base.UBX (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/base.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/base.nav
#
# scanning: 2025/12/06 12:32:07 GRESC
# 2025/12/06 12:20:40-12/06 12:32:07: O=3435 N=110 E=780
# 2026-03-02 15:03:40,283 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2026-03-02 15:03:40,542 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 301699 observations across 1375 epochs
# 2026-03-02 15:03:40,552 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-03-02 15:03:40,552 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk'
# 2026-03-02 15:03:40,553 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:03:46,499 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/report_rover.md
# 2026-03-02 15:03:46,499 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-03-02 15:03:47,135 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 755756 observations across 3435 epochs
# 2026-03-02 15:03:47,156 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-03-02 15:03:47,158 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk'
# 2026-03-02 15:03:47,158 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:03:59,219 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/report_base.md
# 2026-03-02 15:03:59,219 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260302_150339
# 2026-03-02 15:03:59,221 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/rev_20260302_150339/optimized.conf
# 2026-03-02 15:03:59,977 - pils.analyze.ppkdata.PPK.report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/rev_20260302_150339'
# 2026-03-02 15:04:01,774 - pils.analyze.ppkdata.PPK.report - INFO - RTKLIB Quality Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1231/proc/ppk/rev_20260302_150339/report.md
# 2026-03-02 15:04:01,776 - pils.analyze.ppk - INFO - Parsed position: 374 epochs
# 2026-03-02 15:04:01,813 - pils.analyze.ppk - INFO - Parsed statistics: 29132 records
# 2026-03-02 15:04:01,826 - pils.analyze.ppk - INFO - Saved version rev_20260302_150339 to HDF5
# 2026-03-02 15:04:01,826 - pils.analyze.ppk - INFO - PPK analysis complete: rev_20260302_150339
# 2026-03-02 15:04:01,826 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304
# 2026-03-02 15:04:01,827 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/aux/sensors/20251206_130358_GPS.bin (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rover.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rover.nav
#
# scanning: 2025/12/06 13:15:23 GRESC
# 2025/12/06 13:02:05-12/06 13:15:24: O=1599 N=45 E=126
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/base/20251206_base.UBX (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/base.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/base.nav
#
# scanning: 2025/12/06 13:05:22 GRESC
# 2026-03-02 15:04:02,337 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2025/12/06 12:52:04-12/06 13:05:23: O=3995 N=142 E=1446
# 2026-03-02 15:04:02,611 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 333397 observations across 1599 epochs
# 2026-03-02 15:04:02,621 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-03-02 15:04:02,622 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk'
# 2026-03-02 15:04:02,622 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:04:08,579 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/report_rover.md
# 2026-03-02 15:04:08,580 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-03-02 15:04:09,363 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 941696 observations across 3995 epochs
# 2026-03-02 15:04:09,390 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-03-02 15:04:09,391 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk'
# 2026-03-02 15:04:09,391 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:04:23,964 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/report_base.md
# 2026-03-02 15:04:23,964 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260302_150401
# 2026-03-02 15:04:23,964 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_150401/optimized.conf
# 2026-03-02 15:04:25,117 - pils.analyze.ppkdata.PPK.report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_150401'
# 2026-03-02 15:04:27,209 - pils.analyze.ppkdata.PPK.report - INFO - RTKLIB Quality Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1304/proc/ppk/rev_20260302_150401/report.md
# 2026-03-02 15:04:27,211 - pils.analyze.ppk - INFO - Parsed position: 596 epochs
# 2026-03-02 15:04:27,273 - pils.analyze.ppk - INFO - Parsed statistics: 48932 records
# 2026-03-02 15:04:27,290 - pils.analyze.ppk - INFO - Saved version rev_20260302_150401 to HDF5
# 2026-03-02 15:04:27,290 - pils.analyze.ppk - INFO - PPK analysis complete: rev_20260302_150401
# 2026-03-02 15:04:27,291 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333
# 2026-03-02 15:04:27,291 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/aux/sensors/20251206_133334_GPS.bin (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/rover.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/rover.nav
#
# scanning: 2025/12/06 13:44:36 GRESC
# 2025/12/06 13:32:25-12/06 13:44:36: O=1462 N=48
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/base/20251206_base.UBX (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/base.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/base.nav
#
# scanning: 2025/12/06 13:34:34 GRESC
# 2025/12/06 13:22:25-12/06 13:34:35: O=3650 N=160 E=2030
# 2026-03-02 15:04:27,875 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2026-03-02 15:04:28,144 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 328212 observations across 1462 epochs
# 2026-03-02 15:04:28,154 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-03-02 15:04:28,155 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk'
# 2026-03-02 15:04:28,155 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:04:34,069 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/report_rover.md
# 2026-03-02 15:04:34,069 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-03-02 15:04:34,791 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 875118 observations across 3650 epochs
# 2026-03-02 15:04:34,815 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-03-02 15:04:34,817 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk'
# 2026-03-02 15:04:34,817 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:04:48,457 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/report_base.md
# 2026-03-02 15:04:48,458 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260302_150427
# 2026-03-02 15:04:48,458 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/rev_20260302_150427/optimized.conf
# 2026-03-02 15:04:54,823 - pils.analyze.ppkdata.PPK.report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/rev_20260302_150427'
# 2026-03-02 15:04:56,362 - pils.analyze.ppkdata.PPK.report - INFO - RTKLIB Quality Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1333/proc/ppk/rev_20260302_150427/report.md
# 2026-03-02 15:04:56,364 - pils.analyze.ppk - INFO - Parsed position: 460 epochs
# 2026-03-02 15:04:56,413 - pils.analyze.ppk - INFO - Parsed statistics: 38104 records
# 2026-03-02 15:04:56,426 - pils.analyze.ppk - INFO - Saved version rev_20260302_150427 to HDF5
# 2026-03-02 15:04:56,427 - pils.analyze.ppk - INFO - PPK analysis complete: rev_20260302_150427
# 2026-03-02 15:04:56,442 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404
# 2026-03-02 15:04:56,443 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/aux/sensors/20251206_140406_GPS.bin (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/rover.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/rover.nav
#
# scanning: 2025/12/06 14:15:26 GRESC
# 2025/12/06 14:00:42-12/06 14:15:26: O=1770 N=55
# input file  : /mnt/data/POLOCALC/campaigns/202511/20251206/base/20251206_base.UBX (u-blox UBX)
# ->rinex obs : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/base.obs
# ->rinex nav : /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/base.nav
#
# scanning: 2025/12/06 14:05:26 GRESC
# 2025/12/06 13:50:41-12/06 14:05:26: O=4425 N=179 E=2646
# 2026-03-02 15:04:57,146 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2026-03-02 15:04:57,470 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 395092 observations across 1770 epochs
# 2026-03-02 15:04:57,481 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-03-02 15:04:57,483 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk'
# 2026-03-02 15:04:57,483 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:05:04,228 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/report_rover.md
# 2026-03-02 15:05:04,228 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-03-02 15:05:05,108 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 1057777 observations across 4425 epochs
# 2026-03-02 15:05:05,138 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-03-02 15:05:05,140 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk'
# 2026-03-02 15:05:05,140 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-03-02 15:05:21,207 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/report_base.md
# 2026-03-02 15:05:21,207 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260302_150456
# 2026-03-02 15:05:21,208 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/rev_20260302_150456/optimized.conf
# 2026-03-02 15:05:22,507 - pils.analyze.ppkdata.PPK.report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251206/flight_20251206_1404/proc/ppk/rev_20260302_150456'

# %%
# Initialize StoutLoader
loader = StoutLoader()

# Load single flight by ID
flight_meta = loader.load_flights_by_date('2025-12-06', '2025-12-06')

# Extract metadata
print("\n" + "=" * 80)
print("FLIGHT METADATA")
print("=" * 80)
print(f"Flight Name:     {flight_meta['flight_name']}")

# Extract key paths
aux_folder = Path(flight_meta['aux_data_folder_path'])
proc_folder = Path(flight_meta['processed_data_folder_path'])
flight_root = aux_folder.parent  # Root flight directory

print(f"\nAux Data:        {aux_folder}")
print(f"Processed Data:  {proc_folder}")
print(f"Flight Root:     {flight_root}")

# Locate GPS binary in sensors folder
sensors_folder = aux_folder / "sensors"
gps_files = list(sensors_folder.glob("*GPS.bin"))

if gps_files:
    rover_ubx = gps_files[0]
    print(f"\n✓ Found rover GPS file: {rover_ubx.name}")
    print(f"  Size: {rover_ubx.stat().st_size / 1024:.1f} KB")
else:
    print("\n⚠️ No GPS.bin file found in sensors folder")
    rover_ubx = None
# Out:
# 2026-02-06 15:53:54.553 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 15:53:54 - stout - WARNING - [authenticated_user] - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-02-06 15:53:54,485 - stout - WARNING - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-02-06 15:53:54.553 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 15:53:54 - stout - INFO - [authenticated_user] - Centralized logging system initialized
# 2026-02-06 15:53:54,554 - pils.loader.stout - INFO - Initialized with stout database, base path: /mnt/data/POLOCALC
# 2026-02-06 15:53:54,554 - pils.loader.stout - INFO - Loading single flight: flight_id=e809e9fe-0dcb-4a70-8300-ac9dceb99d3f, flight_name=None
# 2026-02-06 15:53:54,566 - pils.loader.stout - INFO - Loaded flight: flight_20251201_1515
# Initialized StoutLoader
#
# ================================================================================
# FLIGHT METADATA
# ================================================================================
# Flight Name:     flight_20251201_1515
#
# Aux Data:        /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/aux
# Processed Data:  /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc
# Flight Root:     /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515
#
# ✓ Found rover GPS file: 20251201_151517_GPS.bin
#   Size: 3875.3 KB

# %% [markdown]
# ## PPK Analysis
#
# ### Smart PPK Execution
#
# The PPKAnalysis class provides intelligent execution:
# - **Smart re-run**: Only processes if configuration changes (SHA256 hash check)
# - **Version management**: Automatic timestamped revisions (rev_YYYYMMDD_HHMMSS)
# - **HDF5 persistence**: All versions saved in single ppk_solution.h5 file
#
# If no config file exists, we'll create a basic kinematic processing configuration.

# %%
flight = Flight(flight_meta)
ppk = PPKAnalysis(flight)
# Out:
# 2026-02-06 15:53:54,577 - pils.analyze.ppk - INFO - Initialized PPKAnalysis for flight: /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515
# 2026-02-06 15:53:54,578 - pils.analyze.ppk - INFO - PPK directory: /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk

# %%
ppk.run_analysis('/scratch/RTK Tests/optimized.conf', force=True, analyze_rinex=True, analyze_ppk=True)
# Out:
# 2026-02-06 15:53:54,600 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: rover.obs
# 2026-02-06 15:53:54,931 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 377193 observations across 1439 epochs
# 2026-02-06 15:53:54,943 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from rover.nav
# 2026-02-06 15:53:54,944 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk'
# 2026-02-06 15:53:54,944 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-02-06 15:54:01,583 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk/report_rover.md
# 2026-02-06 15:54:01,584 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing RINEX file: base.obs
# 2026-02-06 15:54:02,415 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsed 985730 observations across 3595 epochs
# 2026-02-06 15:54:02,444 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Parsing NAV data from base.nav
# 2026-02-06 15:54:02,445 - pils.analyze.ppkdata.RINEX.report - INFO - Generating RINEX quality report in '/mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk'
# 2026-02-06 15:54:02,446 - pils.analyze.ppkdata.RINEX.analyzer - INFO - Computing precise Az/El from NAV ephemeris
# 2026-02-06 15:54:16,328 - pils.analyze.ppkdata.RINEX.report - INFO - Report generated: /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk/report_base.md
# 2026-02-06 15:54:16,328 - pils.analyze.ppk - INFO - Running PPK analysis: rev_20260206_155354
# 2026-02-06 15:54:16,328 - pils.analyze.ppk - INFO - Copied config to /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk/rev_20260206_155354/optimized.conf
# 2026-02-06 15:54:17,249 - pils.analyze.ppkdata.PPK.ppk_report - INFO - Generating RTKLIB Quality Report in '/mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk/rev_20260206_155354'
# 2026-02-06 15:54:19,114 - pils.analyze.ppkdata.PPK.ppk_report - INFO - RTKLIB Quality Report generated: /mnt/data/POLOCALC/campaigns/202511/20251201/flight_20251201_1515/proc/ppk/rev_20260206_155354/report.md
# 2026-02-06 15:54:19,116 - pils.analyze.ppk - INFO - Parsed position: 438 epochs
# 2026-02-06 15:54:19,163 - pils.analyze.ppk - INFO - Parsed statistics: 36588 records
# 2026-02-06 15:54:19,176 - pils.analyze.ppk - INFO - Saved version rev_20260206_155354 to HDF5
# 2026-02-06 15:54:19,177 - pils.analyze.ppk - INFO - PPK analysis complete: rev_20260206_155354
# PPKVersion(version_name='rev_20260206_155354', pos_data=shape: (438, 14)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────┬───────────┬───────────┬───────────┐
# │ time       ┆ lat        ┆ lon        ┆ height    ┆ … ┆ ratio ┆ east      ┆ north     ┆ up        │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ ---   ┆ ---       ┆ ---       ┆ ---       │
# │ datetime[μ ┆ f64        ┆ f64        ┆ f64       ┆   ┆ f64   ┆ f64       ┆ f64       ┆ f64       │
# │ s]         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════╪═══════════╪═══════════╪═══════════╡
# │ 2025-12-01 ┆ -22.959771 ┆ -67.78689  ┆ 5186.1466 ┆ … ┆ 0.0   ┆ 49.623639 ┆ 161.47861 ┆ -134.9096 │
# │ 15:14:37   ┆            ┆            ┆           ┆   ┆       ┆           ┆ 8         ┆ 47        │
# │ 2025-12-01 ┆ -22.959771 ┆ -67.78689  ┆ 5186.1768 ┆ … ┆ 0.0   ┆ 49.636674 ┆ 161.47052 ┆ -134.8794 │
# │ 15:14:37.5 ┆            ┆            ┆           ┆   ┆       ┆           ┆ 7         ┆ 46        │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# │ 2025-12-01 ┆ -22.959771 ┆ -67.78689  ┆ 5186.2104 ┆ … ┆ 0.0   ┆ 49.62836  ┆ 161.47961 ┆ -134.8458 │
# │ 15:14:38   ┆            ┆            ┆           ┆   ┆       ┆           ┆ 7         ┆ 47        │
# │ 2025-12-01 ┆ -22.959771 ┆ -67.78689  ┆ 5186.2408 ┆ … ┆ 0.0   ┆ 49.623126 ┆ 161.47850 ┆ -134.8154 │
# │ 15:14:38.5 ┆            ┆            ┆           ┆   ┆       ┆           ┆ 9         ┆ 47        │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# │ 2025-12-01 ┆ -22.959771 ┆ -67.78689  ┆ 5186.2545 ┆ … ┆ 0.0   ┆ 49.625179 ┆ 161.4866  ┆ -134.8017 │
# │ 15:14:39   ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆ 47        │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …     ┆ …         ┆ …         ┆ …         │
# │ 2025-12-01 ┆ -22.962947 ┆ -67.788404 ┆ 5558.1039 ┆ … ┆ 0.0   ┆ -105.7741 ┆ -190.4933 ┆ 237.04616 │
# │ 15:18:13.5 ┆            ┆            ┆           ┆   ┆       ┆ 88        ┆ 52        ┆ 6         │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# │ 2025-12-01 ┆ -22.962942 ┆ -67.788404 ┆ 5558.5852 ┆ … ┆ 0.0   ┆ -105.7662 ┆ -189.9193 ┆ 237.52748 │
# │ 15:18:14   ┆            ┆            ┆           ┆   ┆       ┆ 97        ┆ 23        ┆ 4         │
# │ 2025-12-01 ┆ -22.962937 ┆ -67.788404 ┆ 5558.9834 ┆ … ┆ 0.0   ┆ -105.7632 ┆ -189.3992 ┆ 237.92569 │
# │ 15:18:14.5 ┆            ┆            ┆           ┆   ┆       ┆ 28        ┆ 71        ┆ 9         │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# │ 2025-12-01 ┆ -22.962935 ┆ -67.788404 ┆ 5558.9836 ┆ … ┆ 0.0   ┆ -105.7612 ┆ -189.1384 ┆ 237.92590 │
# │ 15:18:15   ┆            ┆            ┆           ┆   ┆       ┆ 8         ┆ 63        ┆ 7         │
# │ 2025-12-01 ┆ -22.962937 ┆ -67.788404 ┆ 5558.5133 ┆ … ┆ 0.0   ┆ -105.7836 ┆ -189.3619 ┆ 237.4556  │
# │ 15:18:15.5 ┆            ┆            ┆           ┆   ┆       ┆ 46        ┆ 04        ┆           │
# │ 00         ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴───────┴───────────┴───────────┴───────────┘, stat_data=shape: (36_588, 12)
# ┌──────────┬───────────┬───────────┬─────────┬───┬──────┬──────┬────────┬───────────────┐
# │ tow      ┆ satellite ┆ frequency ┆ azimuth ┆ … ┆ slip ┆ lock ┆ reject ┆ constellation │
# │ ---      ┆ ---       ┆ ---       ┆ ---     ┆   ┆ ---  ┆ ---  ┆ ---    ┆ ---           │
# │ f64      ┆ str       ┆ i64       ┆ f64     ┆   ┆ i64  ┆ i64  ┆ i64    ┆ str           │
# ╞══════════╪═══════════╪═══════════╪═════════╪═══╪══════╪══════╪════════╪═══════════════╡
# │ 141277.0 ┆ G08       ┆ 1         ┆ 223.0   ┆ … ┆ 0    ┆ -4   ┆ 0      ┆ G             │
# │ 141277.0 ┆ G08       ┆ 2         ┆ 223.0   ┆ … ┆ 1    ┆ -4   ┆ 0      ┆ G             │
# │ 141277.0 ┆ G10       ┆ 1         ┆ 112.7   ┆ … ┆ 0    ┆ -4   ┆ 0      ┆ G             │
# │ 141277.0 ┆ G10       ┆ 2         ┆ 112.7   ┆ … ┆ 0    ┆ -4   ┆ 0      ┆ G             │
# │ 141277.0 ┆ G16       ┆ 1         ┆ 268.2   ┆ … ┆ 0    ┆ -4   ┆ 0      ┆ G             │
# │ …        ┆ …         ┆ …         ┆ …       ┆ … ┆ …    ┆ …    ┆ …      ┆ …             │
# │ 141277.0 ┆ E25       ┆ 2         ┆ 354.4   ┆ … ┆ 0    ┆ -5   ┆ 0      ┆ E             │
# │ 141277.0 ┆ E34       ┆ 1         ┆ 268.7   ┆ … ┆ 0    ┆ 0    ┆ 0      ┆ E             │
# │ 141277.0 ┆ E34       ┆ 2         ┆ 268.7   ┆ … ┆ 0    ┆ 0    ┆ 0      ┆ E             │
# │ 141277.0 ┆ E36       ┆ 1         ┆ 205.2   ┆ … ┆ 0    ┆ 0    ┆ 0      ┆ E             │
# │ 141277.0 ┆ E36       ┆ 2         ┆ 205.2   ┆ … ┆ 0    ┆ 0    ┆ 0      ┆ E             │
# └──────────┴───────────┴───────────┴─────────┴───┴──────┴──────┴────────┴───────────────┘, metadata={'config_hash': '301277a7b34edd4705deaf6d89eadc64ac1c427cbfca18b9b4a0a486c7615332', 'timestamp': '2026-02-06T15:54:19.163662', 'config_params': {'pos1-posmode': 'kinematic  # (0:single,1:dgps,2:kinematic,3:static,4:static-start,5:movingbase,6:fixed,7:ppp-kine,8:ppp-static,9:ppp-fixed)', 'pos1-frequency': 'l1+l2      # (1:l1,2:l1+l2,3:l1+l2+l5,4:l1+l2+l5+l6)', 'pos1-soltype': 'combined   # (0:forward,1:backward,2:combined,3:combined-nophasereset)', 'pos1-elmask': '10         # (deg)', 'pos1-snrmask_r': 'on         # (0:off,1:on)', 'pos1-snrmask_b': 'off        # (0:off,1:on)', 'pos1-snrmask_L1': '35,30,30,30,30,30,30,30,30', 'pos1-snrmask_L2': '35,30,30,30,30,30,30,30,30', 'pos1-snrmask_L5': '35,35,35,35,35,35,35,35,35', 'pos1-snrmask_L6': '35,35,35,35,35,35,35,35,35', 'pos1-dynamics': 'on         # (0:off,1:on)', 'pos1-tidecorr': '0          # (1:solid+2:otl+4:spole)', 'pos1-ionoopt': 'brdc       # (0:off,1:brdc,2:sbas,3:dual-freq,4:est-stec,5:ionex-tec,6:qzs-brdc)', 'pos1-tropopt': 'saas      # (0:off,1:saas,2:sbas,3:est-ztd,4:est-ztdgrad)', 'pos1-sateph': 'brdc       # (0:brdc,1:precise,2:brdc+sbas,3:brdc+ssrapc,4:brdc+ssrcom)', 'pos1-posopt1': 'off        # (0:off,1:on)', 'pos1-posopt2': 'off        # (0:off,1:on)', 'pos1-posopt3': 'off        # (0:off,1:on,2:precise)', 'pos1-posopt4': 'off        # (0:off,1:on)', 'pos1-posopt5': 'off        # (0:off,1:on)', 'pos1-posopt6': 'off        # (0:off,1:on)', 'pos1-exclsats': '# (prn ...)', 'pos1-navsys': '13 # (1:gps+2:sbas+4:glo+8:gal+16:qzs+32:bds+64:navic)', 'pos2-armode': 'fix-and-hold # (0:off,1:continuous,2:instantaneous,3:fix-and-hold)', 'pos2-gloarmode': 'autocal        # (0:off,1:on,2:autocal,3:fix-and-hold)', 'pos2-bdsarmode': 'off        # (0:off,1:on)', 'pos2-arfilter': 'on         # (0:off,1:on)', 'pos2-arthres': '3', 'pos2-arthresmin': '3', 'pos2-arthresmax': '3', 'pos2-arthres1': '0.1', 'pos2-arthres2': '0', 'pos2-arthres3': '1e-09', 'pos2-arthres4': '1e-05', 'pos2-varholdamb': '0.1        # (cyc^2)', 'pos2-gainholdamb': '0.01', 'pos2-arlockcnt': '5', 'pos2-minfixsats': '6', 'pos2-minholdsats': '5', 'pos2-mindropsats': '10', 'pos2-arelmask': '15         # (deg)', 'pos2-arminfix': '10', 'pos2-armaxiter': '1', 'pos2-elmaskhold': '15         # (deg)', 'pos2-aroutcnt': '10', 'pos2-maxage': '100        # (s)', 'pos2-syncsol': 'off        # (0:off,1:on)', 'pos2-slipthres': '0.05       # (m)', 'pos2-dopthres': '0          # (m)', 'pos2-rejionno': '3         # (m)', 'pos2-rejcode': '5         # (m)', 'pos2-niter': '2', 'pos2-baselen': '0          # (m)', 'pos2-basesig': '0          # (m)', 'out-solformat': 'llh        # (0:llh,1:xyz,2:enu,3:nmea)', 'out-outhead': 'on         # (0:off,1:on)', 'out-outopt': 'on         # (0:off,1:on)', 'out-outvel': 'off        # (0:off,1:on)', 'out-timesys': 'gpst       # (0:gpst,1:utc,2:jst)', 'out-timeform': 'hms        # (0:tow,1:hms)', 'out-timendec': '3', 'out-degform': 'deg        # (0:deg,1:dms)', 'out-fieldsep': '', 'out-outsingle': 'off        # (0:off,1:on)', 'out-maxsolstd': '0          # (m)', 'out-height': 'ellipsoidal # (0:ellipsoidal,1:geodetic)', 'out-geoid': 'internal   # (0:internal,1:egm96,2:egm08_2.5,3:egm08_1,4:gsi2000)', 'out-solstatic': 'all        # (0:all,1:single)', 'out-nmeaintv1': '0          # (s)', 'out-nmeaintv2': '0          # (s)', 'out-outstat': 'residual   # (0:off,1:state,2:residual)', 'stats-eratio1': '300', 'stats-eratio2': '300', 'stats-eratio5': '300', 'stats-eratio6': '300', 'stats-errphase': '0.01       # (m)', 'stats-errphaseel': '0.02       # (m)', 'stats-errphasebl': '0          # (m/10km)', 'stats-errdoppler': '1          # (Hz)', 'stats-snrmax': '52         # (dB.Hz)', 'stats-errsnr': '0          # (m)', 'stats-errrcv': '0          # ( )', 'stats-stdbias': '30         # (m)', 'stats-stdiono': '0.03       # (m)', 'stats-stdtrop': '0.3        # (m)', 'stats-prnaccelh': '5         # (m/s^2)', 'stats ...
